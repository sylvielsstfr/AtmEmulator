# %% [markdown]
# # Test the Simple atmospheric differential transparency Emulator Using the 1D Vectorisation
#
# - author : Sylvie Dagoret-Campagne
# - affiliation : IJCLab/IN2P3/CNRS
# - creation date : 2023/10/31
# - last update : 2023/10/31
#
#
# - This emulator is based from datagrid of atmospheric transparencies extracted from libradtran
#
# - It is implemented in jax for auto differentiation

# %% [markdown]
# - access to data see https://setuptools.pypa.io/en/latest/userguide/datafiles.html

# %%
import numpy as np
import jax.numpy as jnp
import pandas as pd
import os
import seaborn as sns

# %%
from diffatmpressemulator.diffatmpressemulator  import DiffAtmPressEmulator
from diffatmpressemulator.diffatmpressemulator import Dict_Of_sitesAltitudes,Dict_Of_sitesPressures,final_path_data

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# to enlarge the sizes
params = {'legend.fontsize': 'large',
          'figure.figsize': (16, 8),
         'axes.labelsize': 'xx-large',
         'axes.titlesize':'xx-large',
         'xtick.labelsize':'xx-large',
         'ytick.labelsize':'xx-large'}
plt.rcParams.update(params)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Check emulator

# %%
site = 'LSST'
pressure = 743.0
emul  = DiffAtmPressEmulator(obs_str=site,pressure = pressure)
path = final_path_data
# Out:
# Observatory LSST found in preselected observation sites

# %%
WL = emul.GetWL()

# %%
airmasses = emul.AIRMASS
NAM = len(airmasses)

# %%
hls_colors = sns.color_palette("hls", NAM)
#sns.palplot(hls_colors)

# %% [markdown]
# ## Check emulator with Rayleigh scattering

# %%
fig, ax = plt.subplots()
for idx,am in enumerate(airmasses):
    label = f"am = {am:.1f}" 
    transm = emul.vect1d_Rayleightransparency(WL,am)
    ax.plot(WL,transm,color=hls_colors[idx],label=label)
title = f"DiffAtmPressEmulator : Rayleigh scattering profile"
ax.set_title(title)
ax.set_xlabel("$\lambda$ (nm)")
ax.set_ylabel("transmission")
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax.grid()
ax.legend()

# %% [markdown]
# ## Check emulator with Oxygen O2 absorption

# %%
fig, ax = plt.subplots()
for idx,am in enumerate(airmasses):
    transm = emul.vect1d_O2abstransparency(WL,am)
    label = f"am = {am:.1f}" 
    ax.plot(WL,transm,color=hls_colors[idx],label=label)
title = f"DiffAtmPressEmulator : O2 absorption profile"
ax.set_title(title)
ax.set_xlabel("$\lambda$ (nm)")
ax.set_ylabel("transmission")
ax.set_xlim(600.,800.)
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax.grid()
ax.legend()

# %% [markdown]
# ## Check emulator with PWV absorption

# %%
pwvs = emul.PWV
NPWV=len(pwvs)

# %%
hls_colors = sns.color_palette("hls", NPWV)
sns.palplot(hls_colors)

# %%
am = 1
fig, ax = plt.subplots()

for idx,pwv in enumerate(pwvs):
    am_arr = jnp.array([am])
    pwv_arr = jnp.array([pwv])
    transm = emul.vect1d_PWVabstransparency(WL,am,pwv)
    ax.plot(WL,transm,color=hls_colors[idx])
    
title = f"DiffAtmPressEmulator : H2O absorption profile, airmass = {am:.1f}"
ax.set_title(title)
ax.set_xlabel("$\lambda$ (nm)")
ax.set_ylabel("transmission")
ax.set_xlim(700.,1000.)
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax.grid()
ax.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Check emulator with Ozone absorption

# %%
ozs = emul.OZ
NOZ = len(ozs)

# %%
hls_colors = sns.color_palette("hls", NOZ)
sns.palplot(hls_colors)

# %%
am =1

fig, ax = plt.subplots()

for idx,oz in enumerate(ozs):

    transm = emul.vect1d_OZabstransparency(WL,am,oz)
    ax.plot(WL,transm,color=hls_colors[idx])
    
itle = f"DiffAtmPressEmulator : Ozone absorption profile, am = {am:.1f}"
ax.set_title(title)
ax.set_xlabel("$\lambda$ (nm)")
ax.set_ylabel("transmission")
ax.set_xlim(300.,800.)
ax.set_ylim(0.9,1.0)
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax.grid()
ax.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Check emulator with combined ascattering and absorption process and check with libradtran

# %%
am0 = 1.0
pwv0 = 5.0
oz0 = 500.
transm1 = emul.vect1d_Alltransparencies(WL,am0,pwv0,oz0)
label1=f"emulator : airmass = {am0:.2f}, pwv  = {pwv0:.2f} mm , oz = {oz0:.1f} DU"

# %%
am1 = 2.0
pwv1 = 5.0
oz1 = 500.
transm2 = emul.vect1d_Alltransparencies(WL,am1,pwv1,oz1)
label2=f"emulator : airmass = {am1:.2f},  pwv  = {pwv1:.2f} mm , oz = {oz1:.1f} DU"

# %%
fig, ax = plt.subplots()

ax.plot(WL,transm1,'b-',label=label1)
ax.plot(WL,transm2,'r-',label=label2)

title = f"SimpleDiffAtmEmulator : total transmission, am = {am0:.1f}"
ax.set_title(title)
ax.set_xlabel("$\lambda$ (nm)")
ax.set_ylabel("transmission")
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax.grid()
ax.legend()

# %% [markdown]
# ## Check with aerosols

# %%
hls_colors = sns.color_palette("hls", NAM)
sns.palplot(hls_colors)

# %%
tau = 0.05
beta = - 1.0

fig, ax = plt.subplots()
for idx,am in enumerate(airmasses):

    transm = emul.vect1d_Aerosolstransparency(WL,am,tau,beta)
    label = f"am = {am:.1f}"
    ax.plot(WL,transm,color=hls_colors[idx],label=label)
    
ax.set_ylim(0,1)
title = f"DiffAtmPressEmulator : onecomponents aerosol at different airmasses"
ax.set_title(title)
ax.set_xlabel("$\lambda$ (nm)")
ax.set_ylabel("transmission")
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax.grid()
ax.legend()

# %%
all_taus = [0.01, 0.05, 0.1]
betas = [- 1.0]
beta = betas[0]
ncomp=1
am=1

NTAUS = len(all_taus)

hls_colors = sns.color_palette("hls", NTAUS)
sns.palplot(hls_colors)

# %%
am  = 1

fig, ax = plt.subplots()
for idx,tau in enumerate(all_taus):
    taus = [tau]
    label = f"$\\tau$ = {tau:.2f} , $\\beta$ =  {beta:.2f}"
    transm = emul.vect1d_Aerosolstransparency(WL,am,tau,beta)
    ax.plot(WL,transm,color=hls_colors[idx],label=label)
    
ax.set_ylim(0,1)
title = f"DiffAtmPressEmulator : One component aerosol transmission, am = {am0:.1f}"
ax.set_title(title)
ax.set_xlabel("$\lambda$ (nm)")
ax.set_ylabel("transmission")
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax.grid()
ax.legend()

# %% [markdown]
# ## Test all combined transmission

# %%
hls_colors = sns.color_palette("hls", NAM)
sns.palplot(hls_colors)

# %% [markdown]
# ### Without aerosols

# %%
pwv0 = 5.0
oz0 = 500.

fig, ax = plt.subplots()
for idx,am in enumerate(airmasses):

    transm = emul.vect1d_Alltransparencies(WL,am,pwv0,oz0)
    label = f"am = {am:.1f}"
    ax.plot(WL,transm,color=hls_colors[idx],label=label)
    
ax.set_ylim(0,1)
title = f"DiffAtmPressEmulator : combined transmission - no aerosol"
ax.set_title(title)
ax.set_xlabel("$\lambda$ (nm)")
ax.set_ylabel("transmission")
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax.grid()
ax.legend()

# %% [markdown]
# ### With aerosols

# %%
wv0 = 5.0
oz0 = 500.
ncomp=1
tau= 0.02
beta = -1

fig, ax = plt.subplots()

for idx,am in enumerate(airmasses):

    transm = emul.vect1d_Alltransparencies(WL,am,pwv0,oz0, tau=tau, beta=beta)
    transmnoaer = emul.vect1d_Alltransparencies(WL,am,pwv0,oz0)
    label = f"am = {am:.1f}"
    ax.plot(WL,transm,color=hls_colors[idx],label = label)
    ax.plot(WL,transmnoaer,":",color=hls_colors[idx])
    
ax.set_ylim(0,1)
title = f"DiffAtmPressEmulator : combined transmission - with/without aerosol"
ax.set_title(title)
ax.set_xlabel("$\lambda$ (nm)")
ax.set_ylabel("transmission")
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax.grid()
ax.legend()
