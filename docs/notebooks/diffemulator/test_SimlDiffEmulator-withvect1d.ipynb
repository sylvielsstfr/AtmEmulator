# %% [markdown]
# # Test the Simple atmospheric differential transparency Emulator Using the 1D Vectorisation
#
# - author : Sylvie Dagoret-Campagne
# - affiliation : IJCLab/IN2P3/CNRS
# - creation date : 2023/10/29
# - last update : 2023/10/29
#
#
# - This emulator is based from datagrid of atmospheric transparencies extracted from libradtran
#
# - It is implemented in jax for auto differentiation

# %% [markdown]
# - access to data see https://setuptools.pypa.io/en/latest/userguide/datafiles.html

# %%
import numpy as np
import jax.numpy as jnp
import pandas as pd
import os
import seaborn as sns

# %%
#from simpleemulator.simpleatmemulator import SimpleAtmEmulator,find_data_path
#from simpleemulator.simpleatmemulator import Dict_Of_sitesAltitudes,Dict_Of_sitesPressures

# %%
from diffemulator.diffemulator  import SimpleDiffAtmEmulator,final_path_data
from diffemulator.diffemulator  import Dict_Of_sitesAltitudes,Dict_Of_sitesPressures

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# to enlarge the sizes
params = {'legend.fontsize': 'large',
          'figure.figsize': (16, 8),
         'axes.labelsize': 'xx-large',
         'axes.titlesize':'xx-large',
         'xtick.labelsize':'xx-large',
         'ytick.labelsize':'xx-large'}
plt.rcParams.update(params)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Check emulator

# %%
site = 'LSST'
emul  = SimpleDiffAtmEmulator(obs_str=site)
path = final_path_data
# Out:
# Observatory LSST found in preselected observation sites
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1698592362.848699       1 tfrt_cpu_pjrt_client.cc:349] TfrtCpuClient created.

# %%
emul = SimpleDiffAtmEmulator()
# Out:
# Observatory LSST found in preselected observation sites

# %%
WL = emul.GetWL()

# %%
airmasses = emul.AIRMASS
NAM = len(airmasses)

# %%
hls_colors = sns.color_palette("hls", NAM)
#sns.palplot(hls_colors)

# %% [markdown]
# ## Check emulator with Rayleigh scattering

# %%
fig, ax = plt.subplots()
for idx,am in enumerate(airmasses):
    label = f"am = {am:.1f}" 
    transm = emul.vect1d_Rayleightransparency(WL,am)
    ax.plot(WL,transm,color=hls_colors[idx],label=label)
title = f"SimpleDiffAtmEmulator : Rayleigh scattering profile"
ax.set_title(title)
ax.set_xlabel("$\lambda$ (nm)")
ax.set_ylabel("transmission")
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax.grid()
ax.legend()

# %% [markdown]
# ## Check emulator with Oxygen O2 absorption

# %%
fig, ax = plt.subplots()
for idx,am in enumerate(airmasses):
    transm = emul.vect1d_O2abstransparency(WL,am)
    label = f"am = {am:.1f}" 
    ax.plot(WL,transm,color=hls_colors[idx],label=label)
title = f"SimpleDiffAtmEmulator : O2 absorption profile"
ax.set_title(title)
ax.set_xlabel("$\lambda$ (nm)")
ax.set_ylabel("transmission")
ax.set_xlim(600.,800.)
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax.grid()
ax.legend()

# %% [markdown]
# ## Check emulator with PWV absorption

# %%
pwvs = emul.PWV
NPWV=len(pwvs)

# %%
hls_colors = sns.color_palette("hls", NPWV)
sns.palplot(hls_colors)

# %%
am = 1
fig, ax = plt.subplots()

for idx,pwv in enumerate(pwvs):
    am_arr = jnp.array([am])
    pwv_arr = jnp.array([pwv])
    transm = emul.vect1d_H2Oabstransparency(WL,am,pwv)
    ax.plot(WL,transm,color=hls_colors[idx])
    
title = f"SimpleDiffAtmEmulator : H2O absorption profile, airmass = {am:.1f}"
ax.set_title(title)
ax.set_xlabel("$\lambda$ (nm)")
ax.set_ylabel("transmission")
ax.set_xlim(700.,1000.)
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax.grid()
ax.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Check emulator with Ozone absorption

# %%
ozs = emul.OZ
NOZ = len(ozs)

# %%
hls_colors = sns.color_palette("hls", NOZ)
sns.palplot(hls_colors)

# %%
am =1

fig, ax = plt.subplots()

for idx,oz in enumerate(ozs):

    transm = emul.vect1d_OZabstransparency(WL,am,oz)
    ax.plot(WL,transm,color=hls_colors[idx])
    
itle = f"SimpleDiffAtmEmulator : Ozone absorption profile, am = {am:.1f}"
ax.set_title(title)
ax.set_xlabel("$\lambda$ (nm)")
ax.set_ylabel("transmission")
ax.set_xlim(300.,800.)
ax.set_ylim(0.9,1.0)
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax.grid()
ax.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Check emulator with combined ascattering and absorption process and check with libradtran

# %%
am0 = 1.0
pwv0 = 5.0
oz0 = 500.
transm1 = emul.vect1d_Alltransparencies(WL,am0,pwv0,oz0,flagRayleigh=True)
label1=f"emulator : airmass = {am0:.2f}, pwv  = {pwv0:.2f} mm , oz = {oz0:.1f} DU"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/conda_py310/lib/python3.10/site-packages/jax/_src/api_util.py:583, in shaped_abstractify(x)
#     582 try:
# --> 583   return _shaped_abstractify_handlers[type(x)](x)
#     584 except KeyError:
#
# KeyError: <class 'diffemulator.diffemulator.SimpleDiffAtmEmulator'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 4
#       2 pwv0 = 5.0
#       3 oz0 = 500.
# ----> 4 transm1 = emul.vect1d_Alltransparencies(WL,am0,pwv0,oz0,flagRayleigh=True)
#       5 label1=f"emulator : airmass = {am0:.2f}, pwv  = {pwv0:.2f} mm , oz = {oz0:.1f} DU"
#
#     [... skipping hidden 6 frame]
#
# File ~/anaconda3/envs/conda_py310/lib/python3.10/site-packages/jax/_src/api_util.py:574, in _shaped_abstractify_slow(x)
#     572   dtype = dtypes.canonicalize_dtype(x.dtype, allow_extended_dtype=True)
#     573 else:
# --> 574   raise TypeError(
#     575       f"Cannot interpret value of type {type(x)} as an abstract array; it "
#     576       "does not have a dtype attribute")
#     577 return core.ShapedArray(np.shape(x), dtype, weak_type=weak_type,
#     578                         named_shape=named_shape)
#
# TypeError: Cannot interpret value of type <class 'diffemulator.diffemulator.SimpleDiffAtmEmulator'> as an abstract array; it does not have a dtype attribute

# %%
am1 = 2.0
pwv1 = 5.0
oz1 = 500.
transm2 = emul.vect1d_Alltransparencies(WL,am1,pwv1,oz1,flagRayleigh=True)
label2=f"emulator : airmass = {am1:.2f},  pwv  = {pwv1:.2f} mm , oz = {oz1:.1f} DU"

# %%
fig, ax = plt.subplots()

ax.plot(WL,transm1,'b-',label=label1)
ax.plot(WL,transm2,'r-',label=label2)

title = f"SimpleDiffAtmEmulator : total transmission, am = {am0:.1f}"
ax.set_title(title)
ax.set_xlabel("$\lambda$ (nm)")
ax.set_ylabel("transmission")
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax.grid()
ax.legend()

# %% [markdown]
# ## Check with aerosols

# %%
hls_colors = sns.color_palette("hls", NAM)
sns.palplot(hls_colors)

# %%
ncomp=0

fig, ax = plt.subplots()
for idx,am in enumerate(airmasses):

    transm = emul.vect1d_Aerosolstransparency(WL,am,ncomp)
    ax.plot(WL,transm,color=hls_colors[idx])
    
ax.set_ylim(0,1.1)

title = f"SimpleDiffAtmEmulator : no aerosol transmission, am = {am0:.1f}"
ax.set_title(title)
ax.set_xlabel("$\lambda$ (nm)")
ax.set_ylabel("transmission")
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax.grid()
ax.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 6
#       3 fig, ax = plt.subplots()
#       4 for idx,am in enumerate(airmasses):
# ----> 6     transm = emul.vect1d_Aerosolstransparency(WL,am,ncomp)
#       7     ax.plot(WL,transm,color=hls_colors[idx])
#       9 ax.set_ylim(0,1.1)
#
#     [... skipping hidden 5 frame]
#
# File ~/anaconda3/envs/conda_py310/lib/python3.10/site-packages/jax/_src/api_util.py:286, in argnums_partial_except(f, static_argnums, args, allow_invalid)
#     284 static_arg = args[i]
#     285 if not is_hashable(static_arg):
# --> 286   raise ValueError(
#     287       "Non-hashable static arguments are not supported, as this can lead "
#     288       f"to unexpected cache-misses. Static argument (index {i}) of type "
#     289       f"{type(static_arg)} for function {f.__name__} is non-hashable.")
#     290 else:
#     291   fixed_args.append(_HashableWithStrictTypeEquality(static_arg))  # type: ignore
#
# ValueError: Non-hashable static arguments are not supported, as this can lead to unexpected cache-misses. Static argument (index 2) of type <class 'jaxlib.xla_extension.ArrayImpl'> for function vect1d_Aerosolstransparency is non-hashable.

# %%
taus = [0.05, 0.01]
betas = [- 1.0, -2]
ncomp=2

fig, ax = plt.subplots()
for idx,am in enumerate(airmasses):

    transm = emul.GetAerosolsTransparencies1DArray(WL,am,ncomp,taus,betas)
    label = f"am = {am:.1f}"
    ax.plot(WL,transm,color=hls_colors[idx],label=label)
    
ax.set_ylim(0,1)
title = f"SimpleDiffAtmEmulator : two components aerosols at different airmasses"
ax.set_title(title)
ax.set_xlabel("$\lambda$ (nm)")
ax.set_ylabel("transmission")
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax.grid()
ax.legend()

# %%
all_taus = [0.01, 0.05, 0.1]
betas = [- 1.0]
beta = betas[0]
ncomp=1
am=1

NTAUS = len(all_taus)

hls_colors = sns.color_palette("hls", NTAUS)
sns.palplot(hls_colors)

# %%
am  = 1

fig, ax = plt.subplots()
for idx,tau in enumerate(all_taus):
    taus = [tau]
    label = f"$\\tau$ = {tau:.2f} , $\\beta$ =  {beta:.2f}"
    transm = emul.GetAerosolsTransparencies1DArray(WL,am,ncomp,taus,betas)
    ax.plot(WL,transm,color=hls_colors[idx],label=label)
    
ax.set_ylim(0,1)
title = f"SimpleDiffAtmEmulator : One component aerosol transmission, am = {am0:.1f}"
ax.set_title(title)
ax.set_xlabel("$\lambda$ (nm)")
ax.set_ylabel("transmission")
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax.grid()
ax.legend()

# %% [markdown]
# ## Test all combined transmission

# %%
hls_colors = sns.color_palette("hls", NAM)
sns.palplot(hls_colors)

# %% [markdown]
# ### Without aerosols

# %%
pwv0 = 5.0
oz0 = 500.

fig, ax = plt.subplots()
for idx,am in enumerate(airmasses):

    transm = emul.GetAllTransparencies1DArray(WL,am,pwv0,oz0)
    label = f"am = {am:.1f}"
    ax.plot(WL,transm,color=hls_colors[idx],label=label)
    
ax.set_ylim(0,1)
title = f"SimpleDiffAtmEmulator : combined transmission - no aerosol"
ax.set_title(title)
ax.set_xlabel("$\lambda$ (nm)")
ax.set_ylabel("transmission")
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax.grid()
ax.legend()

# %% [markdown]
# ### With aerosols

# %%
wv0 = 5.0
oz0 = 500.
ncomp=1
taus= [0.02]
betas = [-1]

fig, ax = plt.subplots()

for idx,am in enumerate(airmasses):

    transm = emul.GetAllTransparencies1DArray(WL,am,pwv0,oz0,ncomp=ncomp, taus=taus, betas=betas, flagAerosols=True)
    transmnoaer = emul.GetAllTransparencies1DArray(WL,am,pwv0,oz0)
    label = f"am = {am:.1f}"
    ax.plot(WL,transm,color=hls_colors[idx],label = label)
    ax.plot(WL,transmnoaer,":",color=hls_colors[idx])
    
ax.set_ylim(0,1)
title = f"SimpleDiffAtmEmulator : combined transmission - with/without aerosol"
ax.set_title(title)
ax.set_xlabel("$\lambda$ (nm)")
ax.set_ylabel("transmission")
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax.grid()
ax.legend()
