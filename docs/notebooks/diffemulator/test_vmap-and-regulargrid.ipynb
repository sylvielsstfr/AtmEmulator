# %% [markdown]
# # Test vmap and differentiation with grad and hessian
#
# - Voir aussi example google collab : https://colab.research.google.com/drive/1UQA6hQIGKVQdzN2rp3OyDDs--od1hixV?usp=sharing

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# to enlarge the sizes
params = {'legend.fontsize': 'large',
          'figure.figsize': (6, 6),
         'axes.labelsize': 'xx-large',
         'axes.titlesize':'xx-large',
         'xtick.labelsize':'xx-large',
         'ytick.labelsize':'xx-large'}
plt.rcParams.update(params)

# %%
from jax import make_jaxpr
import jax.numpy as jnp
import numpy as np
from jax import grad, jit, vmap,jacobian,jacfwd,jacrev,hessian
from diffemulator.interpolate import RegularGridInterpolator

# %%
def func(x,y):
    return jnp.exp(-x**2-3*y**2)

# %%
def twomap(f):
      # matrice de dim NxM
      # [[f(x_0,y_0),f(x_0,y_1),....,f(x_0,y_M)],
      #  [f(x_1,y_0),f(x_1,y_0),....,f(x_1,y_M)],
      #  ...
      #  [f(x_N,y_0),f(x_N,y_0),....,f(x_N,y_M)]]
      #
      return jit(vmap(vmap(f, in_axes=(0, None)), in_axes=(None, 0))) #le jit est superflu ici.

# %%
def onemap1(f):
    return jit(vmap(f, in_axes=(0, None)))

def onemap2(f):
    return jit(vmap(f, in_axes=(None,0)))

# %%
x = jnp.linspace(-2,2,50)
y = jnp.linspace(-2,2,100)

# %%
xx,yy = jnp.meshgrid(x,y)

# %%
func_array1 = func(xx,yy)
func_array2 = twomap(func)(x,y)

# %%
fig, axs = plt.subplots(1,2,figsize=(12,6))
ax1 = axs[0]
ax2 = axs[1]
ax1.imshow(func_array1,origin="lower",cmap=plt.cm.magma,extent=(x.min(),x.max(),y.min(),y.max()),aspect='auto')
ax2.imshow(func_array2,origin="lower",cmap=plt.cm.magma,extent=(x.min(),x.max(),y.min(),y.max()),aspect='auto')

ax1.set_xlabel("x")
ax1.set_ylabel("y")
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax1.grid()
ax1.legend()

ax2.set_xlabel("x")
ax2.set_ylabel("y")
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax2.grid()
ax2.legend()

title = f"Gaussian 2D"
plt.suptitle(title)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 0.98, 'Gaussian 2D')

# %% [markdown]
# ## First order derivative

# %% [markdown]
# ### derivative step by step

# %%
grad_x = grad(func,argnums=0)
grad_y = grad(func,argnums=1)

# %%
func_grad_x = vmap( vmap(grad_x,in_axes=(0, None) ), in_axes=(None,0) )
func_grad_y = vmap( vmap(grad_y,in_axes=(0, None) ), in_axes=(None,0) )

# %%
func_grad_x_array =  func_grad_x(x,y) 
func_grad_y_array =  func_grad_y(x,y)

# %%
fig, axs = plt.subplots(1,2,figsize=(12,6))
ax1 = axs[0]

ax1.imshow(func_grad_x_array,origin="lower",cmap=plt.cm.magma,extent=(x.min(),x.max(),y.min(),y.max()),aspect='auto')
title = f"df/dx"
ax1.set_title(title)
ax1.set_xlabel("x")
ax1.set_ylabel("y")
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax1.grid()
ax1.legend()

ax2 = axs[1]
ax2.imshow(func_grad_y_array,origin="lower",cmap=plt.cm.magma,extent=(x.min(),x.max(),y.min(),y.max()),aspect='auto')
title = f"df/dy"
ax2.set_title(title)
ax2.set_xlabel("x")
ax2.set_ylabel("y")
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax2.grid()
ax2.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ### Apply grad on both arguments

# %%
grad_func = grad(func,argnums=(0,1))

# %%
map_grad_func = vmap( vmap(grad_func,in_axes=(0, None) ), in_axes=(None,0) )

# %%
map_grad_func_array = map_grad_func(x,y)

# %%
fig, axs = plt.subplots(1,2,figsize=(12,6))
ax1 = axs[0]

ax1.imshow(map_grad_func_array[0],origin="lower",cmap=plt.cm.magma,extent=(x.min(),x.max(),y.min(),y.max()),aspect='auto')
title = f"df/dx"
ax1.set_title(title)
ax1.set_xlabel("x")
ax1.set_ylabel("y")
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax1.grid()
ax1.legend()

ax2 = axs[1]
ax2.imshow(map_grad_func_array[1],origin="lower",cmap=plt.cm.magma,extent=(x.min(),x.max(),y.min(),y.max()),aspect='auto')
title = f"df/dy"
ax2.set_title(title)
ax2.set_xlabel("x")
ax2.set_ylabel("y")
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax2.grid()
ax2.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Second order derivative

# %% [markdown]
# ### Calculation of derivative step by step

# %%
grad_xx = grad(grad_x,argnums=0)
grad_yy = grad(grad_y,argnums=1)
grad_xy = grad(grad_x,argnums=1)
grad_yx = grad(grad_y,argnums=0)

# %%
func_grad_xx = vmap( vmap(grad_xx,in_axes=(0, None) ), in_axes=(None,0) )
func_grad_yy = vmap( vmap(grad_yy,in_axes=(0, None) ), in_axes=(None,0) )
func_grad_xy = vmap( vmap(grad_xy,in_axes=(0, None) ), in_axes=(None,0) )
func_grad_yx = vmap( vmap(grad_yx,in_axes=(0, None) ), in_axes=(None,0) )

# %%
fig, axes = plt.subplots(2,2,figsize=(12,12))
flatten_axes = axes.flatten()
titles = ["d2f/dx2", "d2f/dxdy", "d2f/dydx","d2f/dx2"]
for idx, ax in enumerate(flatten_axes):
    
    if idx == 0:
        array = func_grad_xx(x,y)
    elif idx == 1:
        array = func_grad_xy(x,y)
    elif idx == 2:
        array = func_grad_yx(x,y)
    elif idx == 3:
        array = func_grad_yy(x,y)
        
    ax.imshow(array,origin="lower",cmap=plt.cm.magma,extent=(x.min(),x.max(),y.min(),y.max()),aspect='auto')
    ax.set_title(titles[idx])
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    
plt.tight_layout()

# %% [markdown]
# ### With the Hessian

# %%
hessian_func = hessian(func, argnums=(0, 1))

# %%
print(hessian_func(1.,2.))
# Out:
# ((Array(4.520659e-06, dtype=float32, weak_type=True), Array(5.4247907e-05, dtype=float32, weak_type=True)), (Array(5.4247907e-05, dtype=float32, weak_type=True), Array(0.00031193, dtype=float32, weak_type=True)))

# %%
map_hessian_func = vmap( vmap(hessian_func, in_axes=(0,None)), in_axes=(None,0))

# %%
all_hessian_arrays = map_hessian_func(x,y)

# %%
fig, axes = plt.subplots(2,2,figsize=(12,12))
flatten_axes = axes.flatten()
titles = ["d2f/dx2", "d2f/dxdy", "d2f/dydx","d2f/dx2"]
for idx, ax in enumerate(flatten_axes):
    
    if idx == 0:
        array = all_hessian_arrays[0][0] 
    elif idx == 1:
        array = all_hessian_arrays[0][1] 
    elif idx == 2:
        array = all_hessian_arrays[1][0] 
    elif idx == 3:
        array = all_hessian_arrays[1][1] 
            
    ax.imshow(array,origin="lower",cmap=plt.cm.magma,extent=(x.min(),x.max(),y.min(),y.max()),aspect='auto')
    ax.set_title(titles[idx])
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    
plt.tight_layout()

# %% [markdown]
# # In a class

# %%
class A():
    def __init__(self,a=3):
        self.a = a
        self.func = lambda u,v: jnp.exp(-u**2-a*v**2)
    
    
    def f(self,x,y):
        return twomap(self.func)(x,y)

    def gradf(self,x,y):
        return twomap(grad(self.func,argnums=(0,1)))(x,y)
    
    def hessianf(self,x,y):
        return twomap(hessian(self.func,argnums=(0,1)))(x,y)

# %%
a = A()

# %%
fig, ax = plt.subplots(1,1,figsize=(6,6))

ax.imshow(a.f(x,y),origin="lower",cmap=plt.cm.magma,extent=(x.min(),x.max(),y.min(),y.max()),aspect='auto')


ax.set_xlabel("x")
ax.set_ylabel("y")
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax.grid()
ax.legend()


title = f"Gaussian 2D"
ax.set_title(title)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 1.0, 'Gaussian 2D')

# %%
fig, axs = plt.subplots(1,2,figsize=(12,6))
ax1 = axs[0]

ax1.imshow(a.gradf(x,y)[0],origin="lower",cmap=plt.cm.magma,extent=(x.min(),x.max(),y.min(),y.max()),aspect='auto')
title = f"df/dx"
ax1.set_title(title)
ax1.set_xlabel("x")
ax1.set_ylabel("y")
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax1.grid()
ax1.legend()

ax2 = axs[1]
ax2.imshow(a.gradf(x,y)[1],origin="lower",cmap=plt.cm.magma,extent=(x.min(),x.max(),y.min(),y.max()),aspect='auto')
title = f"df/dy"
ax2.set_title(title)
ax2.set_xlabel("x")
ax2.set_ylabel("y")
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax2.grid()
ax2.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig, axes = plt.subplots(2,2,figsize=(12,12))
flatten_axes = axes.flatten()
titles = ["d2f/dx2", "d2f/dxdy", "d2f/dydx","d2f/dx2"]
for idx, ax in enumerate(flatten_axes):
    
    if idx == 0:
        array = a.hessianf(x,y)[0][0] 
    elif idx == 1:
        array = a.hessianf(x,y)[0][1] 
    elif idx == 2:
        array = a.hessianf(x,y)[1][0] 
    elif idx == 3:
        array = a.hessianf(x,y)[1][1] 
            
    ax.imshow(array,origin="lower",cmap=plt.cm.magma,extent=(x.min(),x.max(),y.min(),y.max()),aspect='auto')
    ax.set_title(titles[idx])
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    
plt.tight_layout()

# %% [markdown]
# # Single map

# %%
vect_func_opt1 = onemap1(func)
vect_func_opt2 = onemap2(func)

# %%
fig, axs = plt.subplots(1,2,figsize=(12,4))
ax1 = axs[0]

ax1.plot(x,vect_func_opt1(x,0))
ax1.set_title("onemap1 : vmap(f, in_axes=(0, None))")
ax1.set_xlabel("x")

ax2 = axs[1]
ax2.plot(y,vect_func_opt2(0,y))
ax2.set_title("onemap2 : vmap(f, in_axes=(None,0))")
ax2.set_xlabel("y")
# Out:
# Text(0.5, 0, 'y')

# %% [markdown]
# # Generate a gridded for the RegularGrid interpolator

# %%
xg, yg  = np.meshgrid(x, y, indexing='ij', sparse=True)
datagrid = func(xg, yg)
griddedfunc = RegularGridInterpolator((x, y), datagrid)
def nfunc(x,y):
    pts = jnp.array([ (x,y) ])
    return griddedfunc(pts)[0]

# %%
nfunc(1.0,0.5)
# Out:
# Array(0.17402679, dtype=float32)

# %%
x = jnp.linspace(-2,2,50)
y = jnp.linspace(-2,2,100)

# %%
func_array = twomap(nfunc)(x,y)

# %%
fig, ax = plt.subplots(1,1,figsize=(6,6))

ax.imshow(func_array,origin="lower",cmap=plt.cm.magma,extent=(x.min(),x.max(),y.min(),y.max()),aspect='auto')


ax.set_xlabel("x")
ax.set_ylabel("y")
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax.grid()
ax.legend()


title = f"Gaussian 2D"
ax.set_title(title)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 1.0, 'Gaussian 2D')

# %%
grad_nfunc = grad(nfunc,argnums=(0,1))
map_grad_nfunc = vmap( vmap(grad_nfunc,in_axes=(0, None) ), in_axes=(None,0) )
map_grad_nfunc_array = map_grad_nfunc(x,y)

# %%
fig, axs = plt.subplots(1,2,figsize=(12,6))
ax1 = axs[0]

ax1.imshow(map_grad_nfunc_array[0],origin="lower",cmap=plt.cm.magma,extent=(x.min(),x.max(),y.min(),y.max()),aspect='auto')
title = f"df/dx"
ax1.set_title(title)
ax1.set_xlabel("x")
ax1.set_ylabel("y")
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax1.grid()
ax1.legend()

ax2 = axs[1]
ax2.imshow(map_grad_nfunc_array[1],origin="lower",cmap=plt.cm.magma,extent=(x.min(),x.max(),y.min(),y.max()),aspect='auto')
title = f"df/dy"
ax2.set_title(title)
ax2.set_xlabel("x")
ax2.set_ylabel("y")
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax2.grid()
ax2.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
hessian_nfunc = hessian(nfunc, argnums=(0, 1))
map_hessian_nfunc = vmap( vmap(hessian_nfunc, in_axes=(0,None)), in_axes=(None,0))
all_hessian_arrays = map_hessian_nfunc(x,y)

# %%
fig, axes = plt.subplots(2,2,figsize=(12,12))
flatten_axes = axes.flatten()
titles = ["d2f/dx2", "d2f/dxdy", "d2f/dydx","d2f/dx2"]
for idx, ax in enumerate(flatten_axes):
    
    if idx == 0:
        array = all_hessian_arrays[0][0] 
    elif idx == 1:
        array = all_hessian_arrays[0][1] 
    elif idx == 2:
        array = all_hessian_arrays[1][0] 
    elif idx == 3:
        array = all_hessian_arrays[1][1] 
            
    ax.imshow(array,origin="lower",cmap=plt.cm.magma,extent=(x.min(),x.max(),y.min(),y.max()),aspect='auto')
    ax.set_title(titles[idx])
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    
plt.tight_layout()

# %% [markdown]
# # Test interpolation with interpax

# %%
from interpax import interp2d,Interpolator2D,Interpolator3D

# %%
Interpolator2D?
# Out:
# Init signature: Interpolator2D(*args, **kwargs)
# Docstring:
# Convenience class for representing a 2D interpolated function.
#
# Parameters
# ----------
# x : ndarray, shape(Nx,)
#     x coordinates of known function values ("knots")
# y : ndarray, shape(Ny,)
#     y coordinates of known function values ("knots")
# f : ndarray, shape(Nx,Ny,...)
#     function values to interpolate
# method : str
#     method of interpolation
#
#     - ``'nearest'``: nearest neighbor interpolation
#     - ``'linear'``: linear interpolation
#     - ``'cubic'``: C1 cubic splines (aka local splines)
#     - ``'cubic2'``: C2 cubic splines (aka natural splines)
#     - ``'catmull-rom'``: C1 cubic centripetal "tension" splines
#     - ``'cardinal'``: C1 cubic general tension splines. If used, can also pass
#       keyword parameter ``c`` in float[0,1] to specify tension
#
# extrap : bool, float, array-like
#     whether to extrapolate values beyond knots (True) or return nan (False),
#     or a specified value to return for query points outside the bounds. Can
#     also be passed as an array or tuple to specify different conditions
#     [[xlow, xhigh],[ylow,yhigh]]
# period : float > 0, None, array-like, shape(2,)
#     periodicity of the function in x, y directions. None denotes no periodicity,
#     otherwise function is assumed to be periodic on the interval [0,period]. Use a
#     single value for the same in both directions.
#
# Notes
# -----
# This class is registered as a PyTree in JAX (it is actually an equinox.Module)
# so should be compatible with standard JAX transformations (jit, grad, vmap, etc.)
# File:           ~/anaconda3/envs/conda_py310/lib/python3.10/site-packages/interpax/_spline.py
# Type:           _ModuleMeta
# Subclasses:

# %%
xp = x
yp = y
griddedfunc = Interpolator2D(xp,yp,datagrid, method="cubic")

# %%
griddedfunc
# Out:
# Interpolator2D(
#   x=f32[50],
#   y=f32[100],
#   f=f32[50,100],
#   derivs={'fx': f32[50,100], 'fy': f32[50,100], 'fxy': f32[50,100]},
#   method='cubic',
#   extrap=False,
#   period=None,
#   axis=0
# )

# %%
xp = x
yp = y
def nfunc(x,y):
    return griddedfunc([x],[y])[0]

# %%
nfunc(1.0,0.5)
# Out:
# Array(0.17376608, dtype=float32)

# %%
x = jnp.linspace(-2,2,50)
y = jnp.linspace(-2,2,100)

# %%
func_array = twomap(nfunc)(x,y)

# %%
fig, ax = plt.subplots(1,1,figsize=(6,6))

ax.imshow(func_array,origin="lower",cmap=plt.cm.magma,extent=(x.min(),x.max(),y.min(),y.max()),aspect='auto')
ax.set_xlabel("x")
ax.set_ylabel("y")
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax.grid()
ax.legend()


title = f"Gaussian 2D"
ax.set_title(title)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 1.0, 'Gaussian 2D')

# %%
grad_nfunc = grad(nfunc,argnums=(0,1))
map_grad_nfunc = vmap( vmap(grad_nfunc,in_axes=(0, None) ), in_axes=(None,0) )
map_grad_nfunc_array = map_grad_nfunc(x,y)

# %%
fig, axs = plt.subplots(1,2,figsize=(12,6))
ax1 = axs[0]

ax1.imshow(map_grad_nfunc_array[0],origin="lower",cmap=plt.cm.magma,extent=(x.min(),x.max(),y.min(),y.max()),aspect='auto')
title = f"df/dx"
ax1.set_title(title)
ax1.set_xlabel("x")
ax1.set_ylabel("y")
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax1.grid()
ax1.legend()

ax2 = axs[1]
ax2.imshow(map_grad_nfunc_array[1],origin="lower",cmap=plt.cm.magma,extent=(x.min(),x.max(),y.min(),y.max()),aspect='auto')
title = f"df/dy"
ax2.set_title(title)
ax2.set_xlabel("x")
ax2.set_ylabel("y")
# place a text box in upper left in axes coords
#ax.text(0.5, 0.05, textboxstr, transform=ax.transAxes, fontsize=14,verticalalignment='bottom', bbox=textboxprops)
ax2.grid()
ax2.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
hessian_nfunc = hessian(nfunc, argnums=(0, 1))
map_hessian_nfunc = vmap( vmap(hessian_nfunc, in_axes=(0,None)), in_axes=(None,0))
all_hessian_arrays = map_hessian_nfunc(x,y)

# %%
fig, axes = plt.subplots(2,2,figsize=(12,12))
flatten_axes = axes.flatten()
titles = ["d2f/dx2", "d2f/dxdy", "d2f/dydx","d2f/dx2"]
for idx, ax in enumerate(flatten_axes):
    
    if idx == 0:
        array = all_hessian_arrays[0][0] 
    elif idx == 1:
        array = all_hessian_arrays[0][1] 
    elif idx == 2:
        array = all_hessian_arrays[1][0] 
    elif idx == 3:
        array = all_hessian_arrays[1][1] 
            
    ax.imshow(array,origin="lower",cmap=plt.cm.magma,extent=(x.min(),x.max(),y.min(),y.max()),aspect='auto')
    ax.set_title(titles[idx])
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    
plt.tight_layout()
